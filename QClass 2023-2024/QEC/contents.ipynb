# %% [markdown]
# <table width="100%"><tr style="background-color:white;">
#     <td style="text-align:left;padding:0px;width:142px'">
#         <a href="https://qworld.net" target="_blank">
#             <img src="qworld/images/QWorld.png"></a></td>
#     <td width="*">&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</td>
#     <!-- ############################################# -->
#     <td style="padding:0px;width:90px;">
#         <img align="right" src="qworld/images/follow_us.png" height="40px"></td>
#     <td style="padding:0px;width:40px;">
#         <a href="https://twitter.com/QWorld19" target="_blank">
#         <img align="right" src="qworld/images/Twitter.png" width="40px"></a> </td>
#     <td style="padding:0px;width:5px;"></td>
#     <td style="padding:0px;width:40px;">
#         <a href="https://www.facebook.com/qworld19/" target="_blank">
#         <img align="right" src="qworld/images/Fb.png"></a></td>
#     <td style="padding:0px;width:5px;"></td>
#     <td style="padding:0px;width:40px;">
#         <a href="https://www.linkedin.com/company/qworld19" target="_blank">
#         <img align="right" src="qworld/images/LinkedIn.png"></a></td>
#     <td style="padding:0px;width:5px;"></td>
#     <td style="padding:0px;width:40px;">
#         <a href="https://youtube.com/QWorld19?sub_confirmation=1" target="_blank">
#         <img align="right" src="qworld/images/YT.png"></a></td>
#     <!-- ############################################# -->
#     <td style="padding:0px;width:60px;">
#         <img align="right" src="qworld/images/join.png" height="40px"></td>
#     <td style="padding:0px;width:40px;">
#         <a href="https://discord.com/invite/akCvr7U87g"
#            target="_blank">
#         <img align="right" src="qworld/images/Discord.png"></a></td>
#     <!-- ############################################# -->
#     <td style="padding:0px;width:72px;">
#         <img align="right" src="qworld/images/w3.png" height="40px"></td>
#     <td style="padding:0px;width:40px;">
#         <a href="https://qworld.net" target="_blank">
#         <img align="right" src="qworld/images/www.png"></a></td>
# </tr></table>

# %% [markdown]
# ## Table of Contents
#
# This material is drawn from the working draft of the online book [A Methods Focused Guide to Quantum Error Correction and Fault-Tolerant Quantum Computation](https://abdullahkhalid.com/qecft/) by Abdullah Khalid.
#
# The sections are marked by which days of the workshop they correspond to.
#
# ### 1. Introduction
#
# [1.1 About this book](chapters/introduction/book.ipynb)
#
# [1.2 Stac installation, and a short guide](chapters/introduction/stac.ipynb) (Day 0)
#
#
# ### 2. The what and why of error-correction
#
# [2.1 Why error-correction and a model for it](chapters/overview/whatandwhy.ipynb) (Day 1)
#
#
# ### 3. Classical error-correction
#
# [3.1 Error-correction by repetition](chapters/cec/repetition.ipynb) (Day 1)
#
# [3.2 The binary field](chapters/cec/binary-field.ipynb) (Day 1)
#
# [3.3 Classical linear codes](chapters/cec/classical-linear-codes.ipynb) (Day 1)
#
# [3.4 Distance of a code](chapters/cec/distance.ipynb) (optional)
#
#
# ### 4. An example-oriented introduction to quantum error-correction
#
# [4.1 Quantum repetition code for bit-flips](chapters/qec-intro/quantum-repetition-code-for-bit-flips.ipynb) (Day 2)
#
# [4.2 Quantum repetition code for phase-flips](chapters/qec-intro/quantum-repetition-code-for-phase-flips.ipynb) (Day 2)
#
# [4.3 The Shor Code](chapters/qec-intro/shor-code.ipynb) (Day 2)
#
# [4.4 Syndrome measurements, an alternate view](chapters/qec-intro/measurements.ipynb) (Day 2)
#
#
# ### 5. Formal development of quantum error-correction
# This chapter is still in the draft stages, has several mistakes, and not used in the workshop.
#
# [5.1 Quantum codes](chapters/qec-formal/quantum-codes.ipynb)
#
# [5.2 Quantum error-correcting codes](chapters/qec-formal/quantum-error-correcting-codes.ipynb)
#
# [5.3 Quantum operations](chapters/qec-formal/quantum-operations.ipynb)
#
#
# ### 6. Stabilizer codes
#
# [6.1 Pauli group](chapters/stabilizer-codes/pauli-group.ipynb) (Day 3)
#
# [6.2 Stabilizer states](chapters/stabilizer-codes/stabilizer-states.ipynb) (Day 3)
#
# [6.3 Stabilizer groups](chapters/stabilizer-codes/stabilizer-groups.ipynb) (Day 3)
#
# [6.4 Stabilizer codes](chapters/stabilizer-codes/stabilizer-codes.ipynb) (Day 3)
#
# [6.5 Vector form of Pauli operators and the generator matrix](chapters/stabilizer-codes/vector-form-of-pauli-operators-and-generator-matrix.ipynb) (Day 4)
#
# [6.6 Some common codes](chapters/stabilizer-codes/some-common-codes.ipynb) (Day 4)
#
# [6.7 Encoding circuits for stabilizer codes](chapters/stabilizer-codes/encoding-circuits-for-stabilizer-codes.ipynb) (Day 4)
#
# [6.8 Decoding circuits for stabilizer codes](chapters/stabilizer-codes/decoding-circuits.ipynb)  (optional)
#
# [6.9 Syndrome measurements for stabilizer codes](chapters/stabilizer-codes/syndrome-measurements.ipynb) (Day 4)
