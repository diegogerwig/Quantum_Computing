# %% [markdown]
# <img src ='data:image/jpeg;base64,...' >

# %% [markdown]
# # プライム・アンバサダー・バッジ - Discord アクティビティー & コミュニティー・イベント

# %% [markdown]
# ## 目次
# - **[ストーリー](#Story)**
# - **[説明書](#Instructions)**
# - **[バッジの解除](#Unlock-Your-Badge)**

# %% [markdown]
# ## ストーリー

# %% [markdown]
# <img src='data:image/png;base64,...'>

# %% [markdown]
# 宇宙開拓者として楽しみにしている最もエキサイティングなことの 1 つは、ファーストコンタクトです！人類と地球外生命体との最初の交流。この出会いには多くのことが絡んでいます。もし彼らの機嫌を損ねれば戦争に発展するリスクもありますが、ファースト・コンタクトが成功すれば、生涯の味方ができるかもしれません。
#
# （ **[Discordの#space-explorationチャネル](https://discord.com/channels/979714492533440533/1108653145116131338)** で、あなたが出会った地球外生命体について教えてください！彼らはどんな姿をしていますか？どこで出会う？惑星で？宇宙船の中？彼らは愛想がいいですか？）
#
# このバッジを解除して、プライム・アンバサダーのランクを獲得し、ファーストコンタクトを成功させましょう。

# %% [markdown]
# <img src= 'data:image/jpeg;base64,...' >

# %% [markdown]
# ## 説明書
#
# プライム・アンバサダー・バッジはコミュニティー・バッジであり、コミュニティー・アクティビティ（Discordアクティビティー＆コミュニティー・イベント）に関連しています。
#
#
# ### このアチーブメントを解除するためのタスク
#
#
# 1. プライム・アンバサダー・バッジ-キックオフ: Discord アクティビティー & コミュニティー・イベント
#  - 日付：未定 [時間]  [ビデオリンク］
#  - 録画はリンク先でご覧いただけます。
# 2.  プライム・アンバサダー対象のコミュニティー・イベントに少なくとも1回参加する。
#  - Quantum Explorers プログラムでは、プライム・アンバサダー資格のある、つまりこのバッジの解除にカウントできるようなゲーム・ジャムなどのイベントを主催したり、協力したりすることがあります。対象となるイベントのお知らせは、 **[#announcements チャネル](https://discord.com/channels/979714492533440533/1101048846559227964)** と **[#q-prime-ambassador チャネル](https://discord.com/channels/979714492533440533/1100411960895488140)** でご確認ください。
#
# または、
#
# 2. 社交的になることで、DiscordのXPレベルを4以上にする。
#  - Discord で仲間の Explorers と交流しましょう。量子のディスカッションに参加したり、一緒に勉強したり、お互いの質問に答えたり、宇宙探査についてチャットするなど。
#  - Quantum Explorerのボット（宇宙人のボブ）が Discord のアクティビティーを監視し、ユーザーに XP（経験点）を割り当てます。活動的であればあるほど、より多くのXPを得ることができます。XP が増えると Discord のレベルが上がります。誰でもレベル 0 の XP から始まります。 **[#sandbox チャネル](https://discord.com/channels/979714492533440533/1101051019607162930)** では、 /rank コマンドであなた個人のランクとレベルを、 /levels コマンドでリーダーボードへのリンクを見ることができます。または、下の重要なリンクにあるリーダーボードのリンクからアクセスしてください。

# %% [markdown]
# <img src ='data:image/png;base64,...'>

# %% [markdown]
# 3. このバッジにはクイズはありません。プライム・アンバサダー・バッジを解除する資格があると思った時に、 **[プライム・アンバサダー資格申請フォーム](https://airtable.com/shr0Y3JPAhcQ3Hlg2)** を提出してください。資格要件を満たしている場合、Admin から個人的に Discord にパスワードが送信されます。Discord の設定で Admin からの DM を受信できるようにしてください。Admin があなたの資格を確認し、メッセージをお送りするまで、最大5営業日かかります。 *パスワードは誰にも教えないでください。* 注意：申請フォームを送信してもバッジの資格がない場合、Admin からの連絡はありません。

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>重要：</b> 私たちは、リンクだけの記載やスパム行為ではなく、教材やリソースに関する有機的な議論を奨励しています。Admin には、XPのためにメッセージを重複させたり、スパムを行ったり、コミュニティーを混乱させたりする人の XP を減らす権利があります。

# %% [markdown]
# **追記：** プライム・アンバサダー・バッジは Quantum Explorers プログラム専用で、参加資格は「プライムアンバサダー対象（Prime Ambassador-eligible）」と明記されたイベント、または Discord レベル4以上のみです。
#
# **[プライム・アンバサダー・ワークブック](https://ibm.box.com/v/qe23-ambassador-48)** はダウンロード可能なPDFで、あなたが完了しなければならないタスクが含まれており、インタラクティブなチェックボックスとメモ欄があります。これを使って進捗状況を確認したり、メモを取ったりすることができます。
#
# プライム・アンバサダー・バッジに関するご質問やディスカッションは、Discord の **[#q-prime-ambassador チャネル](https://discord.com/channels/979714492533440533/1100411960895488140)** をご利用ください。
#
# **重要なリンク**
#
# - **[プライム・アンバサダー・ワークブック](https://ibm.box.com/v/qe23-ambassador-48)**
# - **[#q-prime-ambassador Discord チャネル](https://discord.com/channels/979714492533440533/1100411960895488140)**
# - **[Discord XP リーダーボード](https://mee6.xyz/en/leaderboard/979714492533440533)**
# - **[プライム・アンバサダー資格申請フォーム](https://airtable.com/shr0Y3JPAhcQ3Hlg2)**
# - **[日本語の Discord チャネル](https://discord.com/channels/979714492533440533/1108291979915300895)**

# %% [markdown]
# <img src='data:image/jpeg;base64,...' >

# %% [markdown]
# ## バッジの解除
#
# バッジのロックを解除する準備はできましたか？下のセルにプライム・アンバサダーのパスワードを入力してください。

# %%
password = '' # build your code here

# %%
# Submit your answer using following code
from qc_grader.challenges.quantum_explorers23 import grade_badge2_ex1
 
grade_badge2_ex1(password) # Expected result type: string

# %% [markdown]
# パスワードは正しかったですか？おめでとうございます！
#
# プライム・アンバサダーのアチーブメントを解除するために必要なことは、次のとおりです：
#
# 1.プライム・アンバサダー・バッジの画像を **[このリンク](https://ibm.box.com/s/8qw2b36s0kik5yewa99xy7pqgenbmab2)** からダウンロードしてください。このリンクはパスワードで保護されています。上のセルで送信したものと同じパスワードを入力してください。
# 2. その画像を **[Discord の #level-up チャネル](https://discord.com/channels/979714492533440533/1096012934829854720)** に投稿して、ピカピカの新しい Discordラベルをゲットしてください！バッジのラベルがあなたの Discord ハンドルに表示されるまで、Admin に問い合わせる前に5営業日ほどお待ちください。
